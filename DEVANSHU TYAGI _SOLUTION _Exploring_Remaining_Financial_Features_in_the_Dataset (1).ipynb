# %% [markdown]
# **Run the two cells below before you begin. These will set the notebook to autosave every 10 seconds, import the necessary libraries for this challenge, and set figure appearance.**

# %% [markdown]
# #workdone in PROJECT 2_PROBLEM STATEMENT 2 BY "DEVANSHU TYAGI"

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #import plotting package
 #render plotting automatically
# %matplotlib inline
import matplotlib as mpl #additional plotting functionality
mpl.rcParams['figure.dpi'] = 400 #high resolution figures
mpl.rcParams['font.size'] = 4

# %% [markdown]
# **To begin, import data set `cleaned_data.csv` and create lists of feature names for the remaining financial features: `'BILL_AMT1'`, `'BILL_AMT2'`, `'BILL_AMT3'`, `'BILL_AMT4'`, `'BILL_AMT5'`, `'BILL_AMT6'`,  `'PAY_AMT1'`, `'PAY_AMT2'`, `'PAY_AMT3'`, `'PAY_AMT4'`, `'PAY_AMT5'`, and `'PAY_AMT6'`.**
#
# **Name the features `bill_feats` and `pay_amt_feats`, respectively.**

# %%
# Import the dataset
df = pd.read_csv('cleaned_data.csv')

# %%
# Create lists `bill_feats` and `pay_amt_feats`
bill_feats=['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
pay_amt_feats=['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5','PAY_AMT6']

# %%
bill_feats
# Out:
# ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']

# %%
pay_amt_feats
# Out:
# ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %% [markdown]
# ____________________________________________________________________________________
# **Next, use `.describe()` to examine statistical summaries of the bill amount features**

# %%
df[bill_feats].describe()
# Out:
#            BILL_AMT1      BILL_AMT2      BILL_AMT3      BILL_AMT4  \
# count   26664.000000   26664.000000   26664.000000   26664.000000
# mean    51405.730723   49300.001500   47026.340047   43338.894539
# std     73633.687106   70934.549534   68705.359524   64275.250740
# min   -165580.000000  -69777.000000 -157264.000000 -170000.000000
# 25%      3580.000000    2999.750000    2627.250000    2341.750000
# 50%     22361.000000   21150.000000   20079.500000   19037.000000
# 75%     67649.750000   64395.500000   60360.000000   54727.500000
# max    746814.000000  671563.000000  855086.000000  706864.000000
#
#            BILL_AMT5      BILL_AMT6
# count   26664.000000   26664.000000
# mean    40338.136701   38889.872337
# std     60705.944083   59432.541657
# min    -81334.000000 -339603.000000
# 25%      1745.000000    1256.000000
# 50%     18066.000000   17005.000000
# 75%     50290.500000   49253.750000
# max    823540.000000  699944.000000

# %% [markdown]
# Reflect on what you see. Does it make sense?

# %% [markdown]
# ___________________________________________________________________________________
# **Then you should visualize the bill amount features using a 2 by 3 grid of histogram plots.**
# > Hint: You can use 20 bins for this visualization.

# %%
# plt.figure(figsize=(10,8))
mpl.rcParams['font.size'] = 4
df[bill_feats].hist(layout=(2,3),figsize = (11,8),bins=20,xrot=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000007398D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000005FCD198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000005FEA6A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000006011C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A7D11D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A7F9748>]],
#       dtype=object)

# %% [markdown]
# ________________________________________________________________________
# **Next, obtain the `.describe()` summary of the payment amount features.**

# %%
df[pay_amt_feats].describe()
# Out:
#             PAY_AMT1      PAY_AMT2       PAY_AMT3       PAY_AMT4  \
# count   26664.000000  2.666400e+04   26664.000000   26664.000000
# mean     5704.085771  5.881110e+03    5259.514964    4887.048717
# std     16699.398632  2.121431e+04   17265.439561   15956.349371
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%      1000.000000  8.020000e+02     390.000000     294.750000
# 50%      2114.500000  2.007000e+03    1822.000000    1500.000000
# 75%      5027.000000  5.000000e+03    4556.250000    4050.500000
# max    873552.000000  1.227082e+06  889043.000000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   26664.000000   26664.000000
# mean     4843.729973    5257.843047
# std     15311.721795   17635.468185
# min         0.000000       0.000000
# 25%       242.750000     111.000000
# 50%      1500.000000    1500.000000
# 75%      4082.750000    4015.000000
# max    426529.000000  528666.000000

# %% [markdown]
#     Does this make sense?

# %% [markdown]
# _______________________________________________________________________________________
# **Next, plot a histogram of the bill payment features similar to the bill amount features,
# but also apply some rotation to the x-axis labels with the `xrot` keyword argument
# so that they don't overlap. In any plotting function, you can include the `xrot=<angle>`
# keyword argument to rotate x-axis labels by a given angle in degrees.**

# %%
# plt.figure(figsize=(10,8))
mpl.rcParams['font.size'] = 4
df[pay_amt_feats].hist(layout=(2,3),figsize = (11,8),bins=20,xrot=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A07FEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000732ACC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000006043240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000060687B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000006092D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000073732E8>]],
#       dtype=object)

# %% [markdown]
#     Consider these results.

# %% [markdown]
# ______________________________________________________________________________________________
# **Then, use a Boolean mask to see how many of the payment amount data are exactly equal to 0. Review the results of the generated mask using `.head()` and `.sum()`.**

# %%
# Create Boolean mask
billpayment_zero_mask = df[pay_amt_feats] == 0

# %%
# Use `.head()`
billpayment_zero_mask.head()
# Out:
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0      True     False      True      True      True      True
# 1      True     False     False     False      True     False
# 2     False     False     False     False     False     False
# 3     False     False     False     False     False     False
# 4     False     False     False     False     False     False

# %%
# Use `.sum()`
billpayment_zero_mask.sum()
# Out:
# PAY_AMT1    4656
# PAY_AMT2    4833
# PAY_AMT3    5293
# PAY_AMT4    5697
# PAY_AMT5    5981
# PAY_AMT6    6373
# dtype: int64

# %% [markdown]
#      Does this make sense given the histogram in the previous step?

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# **Finally, ignoring the payments of 0 using the mask you created in the previous step, use pandas `.apply()` and NumPy's `np.log10()` to plot histograms of logarithmic transformations of the non-zero payments.**
# > Hint: You can use `.apply()` to apply any function, including `log10`, to all the elements of a DataFrame or a column using the following syntax: `.apply(<function_name>)`.

# %%
~billpayment_zero_mask
# Out:
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0         False      True     False     False     False     False
# 1         False      True      True      True     False      True
# 2          True      True      True      True      True      True
# 3          True      True      True      True      True      True
# 4          True      True      True      True      True      True
# 5          True      True      True      True      True      True
# 6          True      True      True      True      True      True
# 7          True      True     False      True      True      True
# 8          True     False      True      True      True      True
# 9         False     False     False      True      True     False
# 10         True      True      True      True      True      True
# 11         True      True      True      True     False      True
# 12         True      True      True      True      True     False
# 13         True     False      True      True      True     False
# 14         True      True      True      True      True      True
# 15        False      True      True      True      True      True
# 16         True     False      True     False      True     False
# 17        False     False     False     False     False     False
# 18        False     False     False     False     False     False
# 19         True      True      True      True      True      True
# 20         True      True     False      True      True     False
# 21         True      True     False      True     False      True
# 22         True      True      True     False     False      True
# 23         True     False      True      True      True      True
# 24         True      True      True      True      True      True
# 25        False      True     False      True     False      True
# 26         True      True      True      True      True      True
# 27         True      True      True      True      True     False
# 28         True      True      True      True      True      True
# 29         True      True      True      True      True      True
# ...         ...       ...       ...       ...       ...       ...
# 26634      True      True     False     False     False     False
# 26635      True      True      True      True      True      True
# 26636      True      True      True      True      True      True
# 26637      True      True      True      True      True      True
# 26638      True      True      True      True      True      True
# 26639      True      True      True      True      True      True
# 26640     False      True     False     False      True      True
# 26641      True     False      True     False      True     False
# 26642      True      True      True      True      True      True
# 26643      True      True      True      True      True      True
# 26644     False     False     False     False     False     False
# 26645      True      True      True      True      True      True
# 26646      True      True     False      True      True      True
# 26647      True      True      True      True      True     False
# 26648      True      True      True      True      True      True
# 26649     False     False     False     False     False     False
# 26650     False     False     False     False     False     False
# 26651      True      True      True      True      True      True
# 26652      True      True      True      True      True      True
# 26653      True     False      True     False     False     False
# 26654      True      True      True      True      True      True
# 26655     False     False     False     False     False     False
# 26656      True     False     False     False     False     False
# 26657      True      True      True      True      True      True
# 26658      True      True     False      True     False      True
# 26659      True      True      True      True      True      True
# 26660      True      True      True      True     False     False
# 26661     False     False      True      True      True      True
# 26662      True      True      True      True      True      True
# 26663      True      True      True      True      True      True
#
# [26664 rows x 6 columns]

# %%
df[pay_amt_feats][~billpayment_zero_mask].apply(np.log10)
# Out:
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0           NaN  2.838219       NaN       NaN       NaN       NaN
# 1           NaN  3.000000  3.000000  3.000000       NaN  3.301030
# 2      3.181272  3.176091  3.000000  3.000000  3.000000  3.698970
# 3      3.301030  3.305136  3.079181  3.041393  3.028978  3.000000
# 4      3.301030  4.564441  4.000000  3.954243  2.838219  2.831870
# 5      3.397940  3.258877  2.817565  3.000000  3.000000  2.903090
# 6      4.740363  4.602060  4.579784  4.306189  4.138303  4.138934
# 7      2.579784  2.778874       NaN  2.764176  3.227115  3.188084
# 8      3.522314       NaN  2.635484  3.000000  3.000000  3.000000
# 9           NaN       NaN       NaN  4.114177  3.049993       NaN
# 10     3.362859  1.079181  1.698970  2.477121  3.572639  1.819544
# 11     4.338815  3.998521  3.933639  4.348324       NaN  3.561101
# 12     3.000000  3.812913  3.812913  3.812913  3.457882       NaN
# 13     3.505150       NaN  3.477121  3.477121  3.176091       NaN
# 14     3.477121  3.477121  3.477121  3.477121  3.477121  3.477121
# 15          NaN  3.176091  3.041393  3.079181  3.113943  3.041393
# 16     3.505150       NaN  3.176091       NaN  3.217484       NaN
# 17          NaN       NaN       NaN       NaN       NaN       NaN
# 18          NaN       NaN       NaN       NaN       NaN       NaN
# 19     3.477121  3.186674  3.000000  3.301030  2.968483  4.528454
# 20     2.499687  2.499687       NaN  2.800717  2.499687       NaN
# 21     3.302547  3.554126       NaN  3.556423       NaN  3.260071
# 22     4.288428  3.168203  2.748188       NaN       NaN  3.052309
# 23     3.760196       NaN  3.732233  3.079181  3.310693  3.301030
# 24     3.295127  3.154120  3.000434  3.155943  3.026125  2.998695
# 25          NaN  3.000000       NaN  2.698970       NaN  3.000000
# 26     3.113943  3.113943  3.000000  3.176091  3.000000  3.005181
# 27     4.237292  4.123231  4.185797  4.155549  4.571616       NaN
# 28     3.235023  3.176091  3.000000  3.000000  3.000000  2.854913
# 29     3.480438  3.545431  3.518777  3.505693  3.505150  3.398634
# ...         ...       ...       ...       ...       ...       ...
# 26634  3.665862  3.301030       NaN       NaN       NaN       NaN
# 26635  3.301030  3.301030  3.000000  3.698970  4.111061  2.778151
# 26636  3.698970  3.339054  3.313656  3.477121  3.989049  3.477121
# 26637  4.723874  4.809795  3.949731  1.724276  4.291901  4.206286
# 26638  3.379306  3.397940  3.403121  3.407561  3.568202  3.477121
# 26639  3.301030  3.587599  4.400158  4.004966  5.171674  3.681241
# 26640       NaN  3.477121       NaN       NaN  3.000000  3.000000
# 26641  3.602060       NaN  3.301030       NaN  3.546543       NaN
# 26642  3.845098  3.845098  3.740363  3.740363  3.748188  3.698970
# 26643  4.001258  3.964637  4.001258  3.905742  3.905256  4.002555
# 26644       NaN       NaN       NaN       NaN       NaN       NaN
# 26645  4.000000  3.602060  3.698970  3.477121  3.653213  3.301030
# 26646  3.361728  3.230449       NaN  2.713491  2.701568  2.767156
# 26647  3.176091  3.176091  3.176091  3.079181  3.397940       NaN
# 26648  3.460898  3.434569  3.460898  3.966752  3.261025  3.230704
# 26649       NaN       NaN       NaN       NaN       NaN       NaN
# 26650       NaN       NaN       NaN       NaN       NaN       NaN
# 26651  3.477121  3.301030  4.968483  3.602060  3.701309  3.602603
# 26652  4.812913  3.944483  3.954773  3.778151  3.845098  3.778802
# 26653  3.956840       NaN  2.893762       NaN       NaN       NaN
# 26654  3.778151  3.845098  3.626135  3.177536  3.301030  3.301030
# 26655       NaN       NaN       NaN       NaN       NaN       NaN
# 26656  3.301030       NaN       NaN       NaN       NaN       NaN
# 26657  3.301030  5.048380  3.602060  3.477121  3.301030  3.301030
# 26658  3.845098  3.544068       NaN  3.845098       NaN  3.602060
# 26659  3.929419  4.301030  3.699231  3.483872  3.698970  3.000000
# 26660  3.264109  3.547282  3.954146  2.110590       NaN       NaN
# 26661       NaN       NaN  4.342423  3.623249  3.301030  3.491362
# 26662  4.933993  3.532627  3.071145  3.284656  4.723981  3.256237
# 26663  3.317646  3.255273  3.155336  3.000000  3.000000  3.000000
#
# [26664 rows x 6 columns]

# %%
df[pay_amt_feats][~billpayment_zero_mask].apply(np.log10).hist(layout=(2,3),figsize = (11,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B4EF470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B528780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B54DCF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8BC2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BC10828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BC39DA0>]],
#       dtype=object)
